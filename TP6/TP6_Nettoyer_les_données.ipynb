# %% [markdown]
# <h1 style="text-align:center;font-size: 4em"> TP6 : Analyse et prédiction des infections COVID-19 </h1>
# <h1 style="text-align:center;"> Nettoyage des données </h1>

# %% [markdown]
# ### Importer les biblio nécessaire

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importer le fichier des données

# %%
dat = pd.read_csv("latestdata.csv")
print('Les noms des colonnes: \n',dat.columns.values)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1,2,9,10,12,13,14,15,16,17,19,20,21,22,23,24,25,26,27,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Les noms des colonnes:
#  ['ID' 'age' 'sex' 'city' 'province' 'country' 'latitude' 'longitude'
#  'geo_resolution' 'date_onset_symptoms' 'date_admission_hospital'
#  'date_confirmation' 'symptoms' 'lives_in_Wuhan' 'travel_history_dates'
#  'travel_history_location' 'reported_market_exposure'
#  'additional_information' 'chronic_disease_binary' 'chronic_disease'
#  'source' 'sequence_available' 'outcome' 'date_death_or_discharge'
#  'notes_for_discussion' 'location' 'admin3' 'admin2' 'admin1'
#  'country_new' 'admin_id' 'data_moderator_initials'
#  'travel_history_binary']

# %%
dat
# Out:
#                   ID  age     sex            city          province  \
# 0            000-1-1  NaN    male        Shek Lei         Hong Kong
# 1           000-1-10   78    male      Vo Euganeo            Veneto
# 2          000-1-100   61  female             NaN               NaN
# 3         000-1-1000  NaN     NaN  Zhengzhou City             Henan
# 4        000-1-10000  NaN     NaN  Pingxiang City           Jiangxi
# ...              ...  ...     ...             ...               ...
# 2676306    010-99995   52  female        Calleria  Coronel Portillo
# 2676307    010-99996   52  female    Pueblo Libre              Lima
# 2676308    010-99997   52  female           Comas              Lima
# 2676309    010-99998   52    male          Callao            Callao
# 2676310    010-99999   52    male      Los Olivos              Lima
#
#            country   latitude   longitude geo_resolution date_onset_symptoms  \
# ...

# %% [markdown]
# ### crée un sous-ensemble de data

# %%
df = dat.loc[:, ['ID', 'age', 'sex', 'symptoms', 'chronic_disease','chronic_disease_binary', 'outcome']]

#df.to_csv('covid_subset.csv', index=False)
#print('The names of all the columns after subseting in the data: \n',df.columns.values)

# %%
df
# Out:
#                   ID  age     sex symptoms chronic_disease  \
# 0            000-1-1  NaN    male      NaN             NaN
# 1           000-1-10   78    male      NaN             NaN
# 2          000-1-100   61  female      NaN             NaN
# 3         000-1-1000  NaN     NaN      NaN             NaN
# 4        000-1-10000  NaN     NaN      NaN             NaN
# ...              ...  ...     ...      ...             ...
# 2676306    010-99995   52  female      NaN             NaN
# 2676307    010-99996   52  female      NaN             NaN
# 2676308    010-99997   52  female      NaN             NaN
# 2676309    010-99998   52    male      NaN             NaN
# 2676310    010-99999   52    male      NaN             NaN
#
#          chronic_disease_binary  \
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# ...                         ...
# ...

# %% [markdown]
# ## Combien de null

# %%
df.isnull().sum(axis = 0)
# Out:
# ID                              0
# age                       2098293
# sex                       2096154
# symptoms                  2674259
# chronic_disease           2676096
# chronic_disease_binary          0
# outcome                   2368929
# dtype: int64

# %% [markdown]
# ## Outcome

# %%
df['outcome'].value_counts()
# Out:
# Hospitalized                                                                202475
# Recovered                                                                    93656
# Deceased                                                                      5011
# recovered                                                                     3659
# died                                                                           916
# Under treatment                                                                370
# Receiving Treatment                                                            257
# Alive                                                                          189
# discharge                                                                      175
# stable                                                                         156
# stable condition                                                               133
# ...

# %%
df['outcome'].fillna('discharged', inplace=True)

# %%
df['outcome'].value_counts()
# Out:
# discharged                                                                  2369046
# Hospitalized                                                                 202475
# Recovered                                                                     93656
# Deceased                                                                       5011
# recovered                                                                      3659
# died                                                                            916
# Under treatment                                                                 370
# Receiving Treatment                                                             257
# Alive                                                                           189
# discharge                                                                       175
# stable                                                                          156
# ...

# %% [markdown]
# ## SEX

# %%
df.isnull().sum(axis = 0)
# Out:
# ID                              0
# age                       2098293
# sex                       2096154
# symptoms                  2674259
# chronic_disease           2676096
# chronic_disease_binary          0
# outcome                         0
# dtype: int64

# %%
df['sex'].value_counts()
# Out:
# male      307188
# female    272969
# Name: sex, dtype: int64

# %%
df['sex'].fillna('male', inplace=True) # car le mode c'est 'male'

# %% [markdown]
# ## AGE

# %%
df = df.dropna(subset=[ 'age'])

# %%
df.shape
# Out:
# (578018, 7)

# %% [markdown]
# ## Symptoms & chronic disese

# %%
df = df.dropna(subset=['symptoms'])

# %%
df['chronic_disease'].fillna('UNKNOWN', inplace=True)

# %% [markdown]
# # Affichage des données après remplissage des valeurs NAN

# %%
df.shape
df
# Out:
#                  ID    age     sex                   symptoms  \
# 476     000-1-10426     60    male    fever, severe pneumonia
# 504     000-1-10451  40-49    male                      fever
# 756     000-1-10679  20-29    male  cough, fever, sore throat
# 765     000-1-10687  40-49    male               cough, fever
# 767     000-1-10689  80-89    male             dyspnea, fever
# ...             ...    ...     ...                        ...
# 658596    005-47758  60-69    male                      cough
# 671470     005-7136  40-49    male                       mild
# 672418     005-7990     35    male       cough, fever, nausea
# 672428        005-8  60-69    male                      cough
# 674650        006-1     39  female                       mild
#
#              chronic_disease  chronic_disease_binary     outcome
# 476                  UNKNOWN                   False  discharged
# 504                  UNKNOWN                   False  discharged
# ...

# %% [markdown]
# # Extraire les informations des variables "symptoms" et "chronic_disease" et les convertir en colones

# %%
df['symptoms'] = df['symptoms'].str.replace(':', ',')
df['symptoms'] = df['symptoms'].str.replace(';', ',')
df['symptoms'] = df['symptoms'].str.replace(', ', ',')
df['symptoms'] = df['symptoms'].str.lower()

# %%
df['symptoms'] = df['symptoms'].str.replace(
    'acute respiratory disease syndrome', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'acute respiratory distress syndrome', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'acute respiratory disease', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'acute respiratory distress', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'acute respiratory failure', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'respiratory stress', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'respiratory symptoms', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'severe acute respiratory infection', 'respiratory problems')
df['symptoms'] = df['symptoms'].str.replace(
    'severe pneumonia', 'pneumonia')
df['symptoms'] = df['symptoms'].str.replace(
    'dry cough', 'cough')

# %%
df
# Out:
#                  ID    age     sex                 symptoms  \
# 476     000-1-10426     60    male          fever,pneumonia
# 504     000-1-10451  40-49    male                    fever
# 756     000-1-10679  20-29    male  cough,fever,sore throat
# 765     000-1-10687  40-49    male              cough,fever
# 767     000-1-10689  80-89    male            dyspnea,fever
# ...             ...    ...     ...                      ...
# 658596    005-47758  60-69    male                    cough
# 671470     005-7136  40-49    male                     mild
# 672418     005-7990     35    male       cough,fever,nausea
# 672428        005-8  60-69    male                    cough
# 674650        006-1     39  female                     mild
#
#              chronic_disease  chronic_disease_binary     outcome
# 476                  UNKNOWN                   False  discharged
# 504                  UNKNOWN                   False  discharged
# ...

# %%
sym = df['symptoms'].str.get_dummies(sep=',')
t = sym.sum()
t
# Out:
#  38 ° c fever          2
#  fever (38 ℃)          2
# 37.1 ° c               2
# 38.7 degrees fever     2
# abdominal pain         6
#                       ..
# vomiting.              2
# weak                   9
# weakness              15
# wheezing               2
# yes                    2
# Length: 281, dtype: int64

# %%
df['chronic_disease'] = df['chronic_disease'].str.replace(':', ',')
df['chronic_disease'] = df['chronic_disease'].str.replace(';', ',')
df['chronic_disease'] = df['chronic_disease'].str.replace(', ', ',')
df['chronic_disease'] = df['chronic_disease'].str.lower()

df['chronic_disease'] = df['chronic_disease'].str.replace(
    ' for more than 20 years', ',')
df['chronic_disease'] = df['chronic_disease'].str.replace(
    ' surgery four years ago', ',')
df['chronic_disease'] = df['chronic_disease'].str.replace(
    ' accident ', ',')
df['chronic_disease'] = df['chronic_disease'].str.replace(
    ' for five years', ',')
df['chronic_disease'] = df['chronic_disease'].str.replace(
    'hypertensive', 'hypertension')
df['chronic_disease'] = df['chronic_disease'].str.replace(
    'hypertenstion', 'hypertension')

cd = df['chronic_disease'].str.get_dummies(sep=',')
v = cd.sum()
v
# Out:
# "thought to have had other pre-existing conditions"       2
# asthma                                                    6
# atherosclerosis                                           2
# atrial fibrillation                                       1
# benign prostatic hyperplasia                              1
# benign prostatic hypertrophy                              1
# bronchial asthma                                          1
# cardiac disease                                           5
# cardiac dysrhythmia                                       1
# cardiomyopathy                                            1
# cardiovascular disease                                    2
# cerebral infarction                                       2
# cerebrovascular                                           1
# cerebrovascular infarct                                   1
# chronic bronchitis                                        3
# chronic kidney disease                                   12
# ...

# %% [markdown]
# ### Choisir les variables qui on plus de 40 valeurs et les convertir en colones

# %%
sym = sym.loc[:, sym.sum() >= 40]
cd = cd.loc[:, cd.sum() >= 40]

# %%
df = pd.concat([df, sym], axis=1)
df = pd.concat([df, cd], axis=1)

# %%
df
# Out:
#                  ID    age     sex                 symptoms  \
# 476     000-1-10426     60    male          fever,pneumonia
# 504     000-1-10451  40-49    male                    fever
# 756     000-1-10679  20-29    male  cough,fever,sore throat
# 765     000-1-10687  40-49    male              cough,fever
# 767     000-1-10689  80-89    male            dyspnea,fever
# ...             ...    ...     ...                      ...
# 658596    005-47758  60-69    male                    cough
# 671470     005-7136  40-49    male                     mild
# 672418     005-7990     35    male       cough,fever,nausea
# 672428        005-8  60-69    male                    cough
# 674650        006-1     39  female                     mild
#
#              chronic_disease  chronic_disease_binary     outcome  \
# 476                  unknown                   False  discharged
# 504                  unknown                   False  discharged
# ...

# %% [markdown]
# ## Convertir tous les variable en deux variables Dead:0 ou Dicharged:1

# %%
df['outcome'] = df['outcome'].str.lower()
df.outcome = np.where(
    df.outcome.isin(['death', 'dead', 'died', 'deceased']),
    0,
    1
)

# %%
df['outcome'].value_counts()
# Out:
# 1    1439
# 0     138
# Name: outcome, dtype: int64

# %% [markdown]
# ## Convertir tous les variable en deux variables female:0 ou male:1

# %%
df.sex = np.where(df.sex == 'male',
         1,
         0
)

# %%
df['sex'].value_counts()
# Out:
# 1    901
# 0    676
# Name: sex, dtype: int64

# %%
df
# Out:
#                  ID    age  sex                 symptoms  \
# 476     000-1-10426     60    1          fever,pneumonia
# 504     000-1-10451  40-49    1                    fever
# 756     000-1-10679  20-29    1  cough,fever,sore throat
# 765     000-1-10687  40-49    1              cough,fever
# 767     000-1-10689  80-89    1            dyspnea,fever
# ...             ...    ...  ...                      ...
# 658596    005-47758  60-69    1                    cough
# 671470     005-7136  40-49    1                     mild
# 672418     005-7990     35    1       cough,fever,nausea
# 672428        005-8  60-69    1                    cough
# 674650        006-1     39    0                     mild
#
#              chronic_disease  chronic_disease_binary  outcome  asymptomatic  \
# 476                  unknown                   False        1             0
# 504                  unknown                   False        1             0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'age', 'sex', 'symptoms', 'chronic_disease',
#        'chronic_disease_binary', 'outcome', 'asymptomatic', 'cough', 'fatigue',
#        'fever', 'headache', 'malaise', 'pneumonia', 'respiratory problems',
#        'runny nose', 'sore throat', 'diabetes', 'hypertension', 'unknown'],
#       dtype='object')

# %%
df.drop(['ID', 'symptoms', 'chronic_disease','unknown'], axis=1, inplace=True)

# %%
df
# Out:
#           age  sex  chronic_disease_binary  outcome  asymptomatic  cough  \
# 476        60    1                   False        1             0      0
# 504     40-49    1                   False        1             0      0
# 756     20-29    1                   False        1             0      1
# 765     40-49    1                   False        1             0      1
# 767     80-89    1                   False        1             0      0
# ...       ...  ...                     ...      ...           ...    ...
# 658596  60-69    1                   False        1             0      1
# 671470  40-49    1                   False        1             0      0
# 672418     35    1                    True        1             0      1
# 672428  60-69    1                   False        1             0      1
# 674650     39    0                   False        1             0      0
#
#         fatigue  fever  headache  malaise  pneumonia  respiratory problems  \
# ...

# %%
df['chronic_disease_binary'].value_counts()
# Out:
# False    1451
# True      126
# Name: chronic_disease_binary, dtype: int64

# %%
df.chronic_disease_binary = np.where(df.chronic_disease_binary == True,
         1,
         0
)

# %%
df['chronic_disease_binary'].value_counts()
# Out:
# 0    1451
# 1     126
# Name: chronic_disease_binary, dtype: int64

# %%
df
# Out:
#           age  sex  chronic_disease_binary  outcome  asymptomatic  cough  \
# 476        60    1                       0        1             0      0
# 504     40-49    1                       0        1             0      0
# 756     20-29    1                       0        1             0      1
# 765     40-49    1                       0        1             0      1
# 767     80-89    1                       0        1             0      0
# ...       ...  ...                     ...      ...           ...    ...
# 658596  60-69    1                       0        1             0      1
# 671470  40-49    1                       0        1             0      0
# 672418     35    1                       1        1             0      1
# 672428  60-69    1                       0        1             0      1
# 674650     39    0                       0        1             0      0
#
#         fatigue  fever  headache  malaise  pneumonia  respiratory problems  \
# ...

# %%
df.dtypes
# Out:
# age                       object
# sex                        int32
# chronic_disease_binary     int32
# outcome                    int32
# asymptomatic               int64
# cough                      int64
# fatigue                    int64
# fever                      int64
# headache                   int64
# malaise                    int64
# pneumonia                  int64
# respiratory problems       int64
# runny nose                 int64
# sore throat                int64
# diabetes                   int64
# hypertension               int64
# dtype: object

# %% [markdown]
# ## Nettoyage du variable AGE

# %%
all_age = df['age'].value_counts().index.tolist()

# %%
all_age
# Out:
# ['50-59',
#  '60-69',
#  '40-49',
#  '70-79',
#  '30-39',
#  '80-89',
#  '20-29',
#  '33',
#  '60',
#  '42',
#  '46',
#  '55',
#  '39',
#  '51',
#  '37',
#  '41',
#  '36',
#  '28',
#  '38',
#  '43',
#  '35',
#  '47',
#  '65',
#  '66',
#  '52',
#  '64',
#  '44',
#  '0-10',
#  '61',
#  '72',
#  '29',
#  '49',
#  '62',
#  '69',
#  '32',
#  '56',
#  '50',
#  '59',
#  '73',
#  '40',
#  '80',
#  '54',
#  '25',
#  '27',
#  '68',
#  '31',
#  '53',
#  '34',
#  '57',
#  '67',
#  '70',
#  '58',
#  '71',
#  '45',
#  '48',
#  '20',
#  42.0,
#  '24',
#  '16',
#  '22',
#  '63',
#  '78',
#  '21',
#  '26',
#  '75',
#  '74',
#  '19',
#  '90-99',
#  '76',
#  '2',
#  '82',
#  '30',
#  '23',
#  27.0,
#  '86',
#  '79',
#  '0.25',
#  '18-60',
#  56.0,
#  '13-19',
#  '89',
#  '60-60',
#  38.0,
#  '83',
#  '81',
#  52.0,
#  69.0,
#  50.0,
#  '50-69',
#  32.0,
#  37.0,
#  '11',
#  '88',
#  40.0,
#  '9',
#  '17',
#  33.0,
#  '87',
#  28.0,
#  '1',
#  '65-',
#  '77',
#  45.0,
#  '0-6',
#  '1.75',
#  '10',
# ...

# %%
df.age = df.age.str.replace('90-99', '95')
df.age = df.age.str.replace('80-89', '85')
df.age = df.age.str.replace('80-', '80')
df.age = df.age.str.replace('70-79', '75')
df.age = df.age.str.replace('65-', '65')
df.age = df.age.str.replace('60-69', '65')
df.age = df.age.str.replace('60-60', '60')
df.age = df.age.str.replace('50-69', '60')
df.age = df.age.str.replace('50-59', '55')
df.age = df.age.str.replace('40-49', '45')
df.age = df.age.str.replace('15-88', '45')
df.age = df.age.str.replace('18-60', '39')
df.age = df.age.str.replace('30-39', '35')
df.age = df.age.str.replace('30-35', '33')
df.age = df.age.str.replace('28-35', '31')
df.age = df.age.str.replace('20-29', '25')
df.age = df.age.str.replace('13-19', '16')
df.age = df.age.str.replace('0-10', '5')
df.age = df.age.str.replace('0-6', '3')


df.age = df.age.astype('float')

# %%
df.isnull().sum(axis = 0)
# Out:
# age                       64
# sex                        0
# chronic_disease_binary     0
# outcome                    0
# asymptomatic               0
# cough                      0
# fatigue                    0
# fever                      0
# headache                   0
# malaise                    0
# pneumonia                  0
# respiratory problems       0
# runny nose                 0
# sore throat                0
# diabetes                   0
# hypertension               0
# dtype: int64

# %% [markdown]
# ### Calculer la moyenne des ages et remplacer NAN par cette valeur

# %%
df['age'].mean()
# Out:
# 50.27263714474554

# %%
df['age'].fillna(50, inplace=True)

# %%
df.age = df.age.astype('int64')

# %%
df
# Out:
#         age  sex  chronic_disease_binary  outcome  asymptomatic  cough  \
# 476      60    1                       0        1             0      0
# 504      45    1                       0        1             0      0
# 756      25    1                       0        1             0      1
# 765      45    1                       0        1             0      1
# 767      85    1                       0        1             0      0
# ...     ...  ...                     ...      ...           ...    ...
# 658596   65    1                       0        1             0      1
# 671470   45    1                       0        1             0      0
# 672418   35    1                       1        1             0      1
# 672428   65    1                       0        1             0      1
# 674650   39    0                       0        1             0      0
#
#         fatigue  fever  headache  malaise  pneumonia  respiratory problems  \
# ...

# %%
df.dtypes
# Out:
# age                       int64
# sex                       int32
# chronic_disease_binary    int32
# outcome                   int32
# asymptomatic              int64
# cough                     int64
# fatigue                   int64
# fever                     int64
# headache                  int64
# malaise                   int64
# pneumonia                 int64
# respiratory problems      int64
# runny nose                int64
# sore throat               int64
# diabetes                  int64
# hypertension              int64
# dtype: object

# %% [markdown]
# # Réorganiser les colonnes

# %%
cols = df.columns.tolist()
cols = cols[0:3] + cols[4:16] + cols[3:4]

# %%
cols
# Out:
# ['age',
#  'sex',
#  'chronic_disease_binary',
#  'asymptomatic',
#  'cough',
#  'fatigue',
#  'fever',
#  'headache',
#  'malaise',
#  'pneumonia',
#  'respiratory problems',
#  'runny nose',
#  'sore throat',
#  'diabetes',
#  'hypertension',
#  'outcome']

# %%
df = df[cols]  #    OR    df = df.ix[:, cols]

# %% [markdown]
# # Notre jeu de données après le nettoyage

# %%
df
# Out:
#         age  sex  chronic_disease_binary  asymptomatic  cough  fatigue  fever  \
# 476      60    1                       0             0      0        0      1
# 504      45    1                       0             0      0        0      1
# 756      25    1                       0             0      1        0      1
# 765      45    1                       0             0      1        0      1
# 767      85    1                       0             0      0        0      1
# ...     ...  ...                     ...           ...    ...      ...    ...
# 658596   65    1                       0             0      1        0      0
# 671470   45    1                       0             0      0        0      0
# 672418   35    1                       1             0      1        0      1
# 672428   65    1                       0             0      1        0      0
# 674650   39    0                       0             0      0        0      0
#
# ...

# %% [markdown]
# # Enregistrer ce jeu données sous format CSV

# %%
df.to_csv('covid_data_cleaned.csv', index=False)

# %% [markdown]
# ***
# ### Réalisé par : AABBOU ZAKARIA
# - [E-mail :](mailto:zakaria.abbou199434@gmail.com) zakaria.abbou199434@gmail.com
# - [GitHub :](https://github.com/ZakariaAABBOU) github.com/ZakariaAABBOU
# - [Linkedin :](https://www.linkedin.com/in/zakaria-aabbou/) linkedin.com/in/zakaria-aabbou/
